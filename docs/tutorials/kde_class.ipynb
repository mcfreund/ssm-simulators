# %% [markdown]
# # Using the KDE class

# %%
import ssms
from ssms.support_utils.kde_class import LogKDE
import numpy as np
from matplotlib import pyplot as plt

# %%
sim_out = ssms.basic_simulators.simulator.simulator(model = 'ddm', theta = dict(v = 1.0, a = 1.5, z = 0.5, t = 0.4), n_samples = 50000)

# %%
my_kde = LogKDE(sim_out,
                bandwidth_type = "silverman",
                auto_bandwidth = True,
                displace_t = False)

# %%
rt_data = {'rts': np.repeat(np.linspace(0, 10, 1000), 2),
           'choices': np.tile([-1, 1], 1000)}

# %%
test_lb = -66.6
kde_out = my_kde.kde_eval(data = rt_data, log_eval = False)

# %%
plt.plot(rt_data['rts'][rt_data['choices'] == 1], 
         kde_out[rt_data['choices'] == 1])
plt.plot(rt_data['rts'][rt_data['choices'] == -1], 
         kde_out[rt_data['choices'] == -1])
plt.xlim(0,10)
# Out:
# (0.0, 10.0)
